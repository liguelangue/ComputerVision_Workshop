# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load and preprocess the image
image = cv2.imread('flower.png')
# Convert BGR to RGB for matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Find contours
contours, hierarchy = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Create a copy for drawing contours
image_with_contours = image_rgb.copy()
# Draw contours on the image
cv2.drawContours(image_with_contours, contours, -1, (0, 255, 0), 2)

# Create figure
plt.figure(figsize=(15, 5))

# Original image
plt.subplot(1, 3, 1)
plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')

# Binary image
plt.subplot(1, 3, 2)
plt.imshow(binary, cmap='gray')
plt.title('Binary Image')
plt.axis('off')

# Image with contours
plt.subplot(1, 3, 3)
plt.imshow(image_with_contours)
plt.title('Contours Detection')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Load and preprocess the image
image = cv2.imread('chair.png')
# Convert BGR to RGB for matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Find contours
contours, hierarchy = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Create a copy for drawing contours
image_with_contours = image_rgb.copy()
# Draw contours on the image
cv2.drawContours(image_with_contours, contours, -1, (0, 255, 0), 2)

# Create figure
plt.figure(figsize=(15, 5))

# Original image
plt.subplot(1, 3, 1)
plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')

# Binary image
plt.subplot(1, 3, 2)
plt.imshow(binary, cmap='gray')
plt.title('Binary Image')
plt.axis('off')

# Image with contours
plt.subplot(1, 3, 3)
plt.imshow(image_with_contours)
plt.title('Contours Detection')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# -------------------- Additional Implementation --------------------
# -------------------- Contour Retrieval Methods --------------------

# Load and preprocess the image
image = cv2.imread('flower.png')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Create figure
plt.figure(figsize=(15, 10))

# Original image
plt.subplot(2, 2, 1)
plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')

# RETR_EXTERNAL
contours_external, _ = cv2.findContours(binary.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
image_external = image_rgb.copy()
cv2.drawContours(image_external, contours_external, -1, (0, 255, 0), 2)
plt.subplot(2, 2, 2)
plt.imshow(image_external)
plt.title(f'RETR_EXTERNAL\n(Found {len(contours_external)} contours)')
plt.axis('off')

# RETR_LIST
contours_list, _ = cv2.findContours(binary.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
image_list = image_rgb.copy()
cv2.drawContours(image_list, contours_list, -1, (0, 255, 0), 2)
plt.subplot(2, 2, 3)
plt.imshow(image_list)
plt.title(f'RETR_LIST\n(Found {len(contours_list)} contours)')
plt.axis('off')

# RETR_TREE
contours_tree, hierarchy = cv2.findContours(binary.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
image_tree = image_rgb.copy()
# Draw contours with different colors based on hierarchy
for i, contour in enumerate(contours_tree):
    # Use different colors for different hierarchy levels
    if hierarchy[0][i][3] == -1:  # External contour
        color = (0, 255, 0)  # Green
    else:  # Internal contour
        color = (255, 0, 0)  # Red
    cv2.drawContours(image_tree, [contour], -1, color, 2)

plt.subplot(2, 2, 4)
plt.imshow(image_tree)
plt.title(f'RETR_TREE\n(Found {len(contours_tree)} contours)')
plt.axis('off')

plt.tight_layout()
plt.show()

# Print hierarchy information for RETR_TREE
print("\nHierarchy information for RETR_TREE:")
print("Format: [Next, Previous, First_Child, Parent]")
for i, h in enumerate(hierarchy[0]):
    print(f"Contour {i}: {h}")
# Out:
# Hierarchy information for RETR_TREE:
# Format: [Next, Previous, First_Child, Parent]
# Contour 0: [ 1 -1 -1 -1]
# Contour 1: [ 2  0 -1 -1]
# Contour 2: [ 3  1 -1 -1]
# Contour 3: [ 4  2 -1 -1]
# Contour 4: [ 5  3 -1 -1]
# Contour 5: [ 6  4 -1 -1]
# Contour 6: [ 7  5 -1 -1]
# Contour 7: [ 8  6 -1 -1]
# Contour 8: [ 9  7 -1 -1]
# Contour 9: [10  8 -1 -1]
# Contour 10: [11  9 -1 -1]
# Contour 11: [12 10 -1 -1]
# Contour 12: [13 11 -1 -1]
# Contour 13: [14 12 -1 -1]
# Contour 14: [15 13 -1 -1]
# Contour 15: [16 14 -1 -1]
# Contour 16: [17 15 -1 -1]
# Contour 17: [18 16 -1 -1]
# Contour 18: [22 17 19 -1]
# Contour 19: [20 -1 -1 18]
# Contour 20: [21 19 -1 18]
# Contour 21: [-1 20 -1 18]
# Contour 22: [23 18 -1 -1]
# Contour 23: [24 22 -1 -1]
# Contour 24: [25 23 -1 -1]
# Contour 25: [26 24 -1 -1]
# Contour 26: [27 25 -1 -1]
# Contour 27: [28 26 -1 -1]
# Contour 28: [29 27 -1 -1]
# Contour 29: [30 28 -1 -1]
# Contour 30: [31 29 -1 -1]
# Contour 31: [32 30 -1 -1]
# ...

# %%
# -------------------- Contour Approximation Methods --------------------
# Load and preprocess the image
image = cv2.imread('flower.png')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Create figure
plt.figure(figsize=(15, 10))

# Original image
plt.subplot(2, 2, 1)
plt.imshow(image_rgb)
plt.title('Original Image')
plt.axis('off')

# Binary image
plt.subplot(2, 2, 2)
plt.imshow(binary, cmap='gray')
plt.title('Binary Image')
plt.axis('off')

# CHAIN_APPROX_NONE
contours_none, _ = cv2.findContours(binary.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
image_none = image_rgb.copy()
cv2.drawContours(image_none, contours_none, -1, (0, 255, 0), 2)

# Count total points in NONE mode
total_points_none = sum(len(cnt) for cnt in contours_none)

plt.subplot(2, 2, 3)
plt.imshow(image_none)
plt.title(f'CHAIN_APPROX_NONE\nTotal Points: {total_points_none}')
plt.axis('off')

# CHAIN_APPROX_SIMPLE
contours_simple, _ = cv2.findContours(binary.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
image_simple = image_rgb.copy()
cv2.drawContours(image_simple, contours_simple, -1, (0, 255, 0), 2)

# Count total points in SIMPLE mode
total_points_simple = sum(len(cnt) for cnt in contours_simple)

plt.subplot(2, 2, 4)
plt.imshow(image_simple)
plt.title(f'CHAIN_APPROX_SIMPLE\nTotal Points: {total_points_simple}')
plt.axis('off')

plt.tight_layout()
plt.show()

# Print detailed information
print("\nDetailed Contour Information:")
print(f"CHAIN_APPROX_NONE:")
print(f"- Total contours: {len(contours_none)}")
print(f"- Total points: {total_points_none}")
for i, cnt in enumerate(contours_none):
    print(f"- Contour {i}: {len(cnt)} points")

print(f"\nCHAIN_APPROX_SIMPLE:")
print(f"- Total contours: {len(contours_simple)}")
print(f"- Total points: {total_points_simple}")
for i, cnt in enumerate(contours_simple):
    print(f"- Contour {i}: {len(cnt)} points")

print(f"\nMemory reduction: {(total_points_none - total_points_simple) / total_points_none * 100:.2f}%")
# Out:
# Detailed Contour Information:
# CHAIN_APPROX_NONE:
# - Total contours: 141
# - Total points: 7065
# - Contour 0: 8 points
# - Contour 1: 8 points
# - Contour 2: 4 points
# - Contour 3: 4 points
# - Contour 4: 8 points
# - Contour 5: 4 points
# - Contour 6: 12 points
# - Contour 7: 4 points
# - Contour 8: 4 points
# - Contour 9: 78 points
# - Contour 10: 4 points
# - Contour 11: 8 points
# - Contour 12: 4 points
# - Contour 13: 63 points
# - Contour 14: 4 points
# - Contour 15: 4 points
# - Contour 16: 4 points
# - Contour 17: 8 points
# - Contour 18: 304 points
# - Contour 19: 4 points
# - Contour 20: 41 points
# - Contour 21: 39 points
# - Contour 22: 4 points
# - Contour 23: 4 points
# - Contour 24: 39 points
# - Contour 25: 4 points
# - Contour 26: 11 points
# - Contour 27: 4 points
# - Contour 28: 4 points
# - Contour 29: 4 points
# - Contour 30: 4 points
# - Contour 31: 4 points
# - Contour 32: 10 points
# - Contour 33: 8 points
# - Contour 34: 4 points
# ...
